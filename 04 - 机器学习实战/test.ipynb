# %%
import keras
import tensorflow as tf
from keras.layers import Dense, Dropout
from keras import metrics
from keras import backend as K
from keras.wrappers.scikit_learn import KerasRegressor

# %%
def create_model():
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu' ))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam',loss='mean_squared_error')
    return model

# %%
import pandas as pd
test_df = pd.read_csv("https://media.githubusercontent.com/media/lizhicq/AI-course/master/04%20-%20%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0%E5%AE%9E%E6%88%98/data/train_1.csv")

# %%
test_df
# Out:
#       Unnamed: 0    Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0              0     1          60       RL    65.000000     8450   Pave
# 1              1     2          20       RL    80.000000     9600   Pave
# 2              2     3          60       RL    68.000000    11250   Pave
# 3              3     4          70       RL    60.000000     9550   Pave
# 4              4     5          60       RL    84.000000    14260   Pave
# 5              5     6          50       RL    85.000000    14115   Pave
# 6              6     7          20       RL    75.000000    10084   Pave
# 7              7     8          60       RL    61.135260    10382   Pave
# 8              8     9          50       RM    51.000000     6120   Pave
# 9              9    10         190       RL    50.000000     7420   Pave
# 10            10    11          20       RL    70.000000    11200   Pave
# 11            11    12          60       RL    85.000000    11924   Pave
# 12            12    13          20       RL    68.326276    12968   Pave
# 13            13    14          20       RL    91.000000    10652   Pave
# 14            14    15          20       RL    62.699282    10920   Pave
# 15            15    16          45       RM    51.000000     6120   Pave
# 16            16    17          20       RL    63.614149    11241   Pave
# 17            17    18          90       RL    72.000000    10791   Pave
# 18            18    19          20       RL    66.000000    13695   Pave
# 19            19    20          20       RL    70.000000     7560   Pave
# 20            20    21          60       RL   101.000000    14215   Pave
# 21            21    22          45       RM    57.000000     7449   Pave
# 22            22    23          20       RL    75.000000     9742   Pave
# 23            23    24         120       RM    44.000000     4224   Pave
# 24            24    25          20       RL    54.484493     8246   Pave
# 25            25    26          20       RL   110.000000    14230   Pave
# 26            26    27          20       RL    60.000000     7200   Pave
# 27            27    28          20       RL    98.000000    11478   Pave
# 28            28    29          20       RL    47.000000    16321   Pave
# 29            29    30          30       RM    60.000000     6324   Pave
# ...          ...   ...         ...      ...          ...      ...    ...
# 1430        1430  1431          60       RL    60.000000    21930   Pave
# 1431        1431  1432         120       RL    42.119829     4928   Pave
# 1432        1432  1433          30       RL    60.000000    10800   Pave
# 1433        1433  1434          60       RL    93.000000    10261   Pave
# 1434        1434  1435          20       RL    80.000000    17400   Pave
# 1435        1435  1436          20       RL    80.000000     8400   Pave
# 1436        1436  1437          20       RL    60.000000     9000   Pave
# 1437        1437  1438          20       RL    96.000000    12444   Pave
# 1438        1438  1439          20       RM    90.000000     7407   Pave
# 1439        1439  1440          60       RL    80.000000    11584   Pave
# 1440        1440  1441          70       RL    79.000000    11526   Pave
# 1441        1441  1442         120       RM    39.916914     4426   Pave
# 1442        1442  1443          60       FV    85.000000    11003   Pave
# 1443        1443  1444          30       RL    56.457418     8854   Pave
# 1444        1444  1445          20       RL    63.000000     8500   Pave
# 1445        1445  1446          85       RL    70.000000     8400   Pave
# 1446        1446  1447          20       RL    97.010927    26142   Pave
# 1447        1447  1448          60       RL    80.000000    10000   Pave
# 1448        1448  1449          50       RL    70.000000    11767   Pave
# 1449        1449  1450         180       RM    21.000000     1533   Pave
# 1450        1450  1451          90       RL    60.000000     9000   Pave
# 1451        1451  1452          20       RL    78.000000     9262   Pave
# 1452        1452  1453         180       RM    35.000000     3675   Pave
# 1453        1453  1454          20       RL    90.000000    17217   Pave
# 1454        1454  1455          20       FV    62.000000     7500   Pave
# 1455        1455  1456          60       RL    62.000000     7917   Pave
# 1456        1456  1457          20       RL    85.000000    13175   Pave
# 1457        1457  1458          70       RL    66.000000     9042   Pave
# 1458        1458  1459          20       RL    68.000000     9717   Pave
# 1459        1459  1460          20       RL    75.000000     9937   Pave
#
#      Alley LotShape LandContour  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0     None      Reg         Lvl  ...   None   None        None       0      2
# 1     None      Reg         Lvl  ...   None   None        None       0      5
# 2     None      IR1         Lvl  ...   None   None        None       0      9
# 3     None      IR1         Lvl  ...   None   None        None       0      2
# 4     None      IR1         Lvl  ...   None   None        None       0     12
# 5     None      IR1         Lvl  ...   None  MnPrv        Shed     700     10
# 6     None      Reg         Lvl  ...   None   None        None       0      8
# 7     None      IR1         Lvl  ...   None   None        Shed     350     11
# 8     None      Reg         Lvl  ...   None   None        None       0      4
# 9     None      Reg         Lvl  ...   None   None        None       0      1
# 10    None      Reg         Lvl  ...   None   None        None       0      2
# 11    None      IR1         Lvl  ...   None   None        None       0      7
# 12    None      IR2         Lvl  ...   None   None        None       0      9
# 13    None      IR1         Lvl  ...   None   None        None       0      8
# 14    None      IR1         Lvl  ...   None   GdWo        None       0      5
# 15    None      Reg         Lvl  ...   None  GdPrv        None       0      7
# 16    None      IR1         Lvl  ...   None   None        Shed     700      3
# 17    None      Reg         Lvl  ...   None   None        Shed     500     10
# 18    None      Reg         Lvl  ...   None   None        None       0      6
# 19    None      Reg         Lvl  ...   None  MnPrv        None       0      5
# 20    None      IR1         Lvl  ...   None   None        None       0     11
# 21    Grvl      Reg         Bnk  ...   None  GdPrv        None       0      6
# 22    None      Reg         Lvl  ...   None   None        None       0      9
# 23    None      Reg         Lvl  ...   None   None        None       0      6
# 24    None      IR1         Lvl  ...   None  MnPrv        None       0      5
# 25    None      Reg         Lvl  ...   None   None        None       0      7
# 26    None      Reg         Lvl  ...   None   None        None       0      5
# 27    None      Reg         Lvl  ...   None   None        None       0      5
# 28    None      IR1         Lvl  ...   None   None        None       0     12
# 29    None      IR1         Lvl  ...   None   None        None       0      5
# ...    ...      ...         ...  ...    ...    ...         ...     ...    ...
# 1430  None      IR3         Lvl  ...   None   None        None       0      7
# 1431  None      IR1         Lvl  ...   None   None        None       0     10
# 1432  Grvl      Reg         Lvl  ...   None   None        None       0      8
# 1433  None      IR1         Lvl  ...   None   None        None       0      5
# 1434  None      Reg         Low  ...   None   None        None       0      5
# 1435  None      Reg         Lvl  ...   None  GdPrv        None       0      7
# 1436  None      Reg         Lvl  ...   None   GdWo        None       0      5
# 1437  None      Reg         Lvl  ...   None   None        None       0     11
# 1438  None      Reg         Lvl  ...   None  MnPrv        None       0      4
# 1439  None      Reg         Lvl  ...   None   None        None       0     11
# 1440  None      IR1         Bnk  ...   None   None        None       0      9
# 1441  None      Reg         Lvl  ...   None   None        None       0      5
# 1442  None      Reg         Lvl  ...   None   None        None       0      4
# 1443  None      Reg         Lvl  ...   None   None        None       0      5
# 1444  None      Reg         Lvl  ...   None   None        None       0     11
# 1445  None      Reg         Lvl  ...   None   None        None       0      5
# 1446  None      IR1         Lvl  ...   None   None        None       0      4
# 1447  None      Reg         Lvl  ...   None   None        None       0     12
# 1448  None      Reg         Lvl  ...   None   GdWo        None       0      5
# 1449  None      Reg         Lvl  ...   None   None        None       0      8
# 1450  None      Reg         Lvl  ...   None   None        None       0      9
# 1451  None      Reg         Lvl  ...   None   None        None       0      5
# 1452  None      Reg         Lvl  ...   None   None        None       0      5
# 1453  None      Reg         Lvl  ...   None   None        None       0      7
# 1454  Pave      Reg         Lvl  ...   None   None        None       0     10
# 1455  None      Reg         Lvl  ...   None   None        None       0      8
# 1456  None      Reg         Lvl  ...   None  MnPrv        None       0      2
# 1457  None      Reg         Lvl  ...   None  GdPrv        Shed    2500      5
# 1458  None      Reg         Lvl  ...   None   None        None       0      4
# 1459  None      Reg         Lvl  ...   None   None        None       0      6
#
#      YrSold SaleType SaleCondition  SalePrice  SqrtLotArea
# 0      2008       WD        Normal     208500    91.923882
# 1      2007       WD        Normal     181500    97.979590
# 2      2008       WD        Normal     223500   106.066017
# 3      2006       WD       Abnorml     140000    97.724101
# 4      2008       WD        Normal     250000   119.415242
# 5      2009       WD        Normal     143000   118.806565
# 6      2007       WD        Normal     307000   100.419122
# 7      2009       WD        Normal     200000   101.892100
# 8      2008       WD       Abnorml     129900    78.230429
# 9      2008       WD        Normal     118000    86.139422
# 10     2008       WD        Normal     129500   105.830052
# 11     2006      New       Partial     345000   109.197070
# 12     2008       WD        Normal     144000   113.877127
# 13     2007      New       Partial     279500   103.208527
# 14     2008       WD        Normal     157000   104.498804
# 15     2007       WD        Normal     132000    78.230429
# 16     2010       WD        Normal     149000   106.023582
# 17     2006       WD        Normal      90000   103.879738
# 18     2008       WD        Normal     159000   117.025638
# 19     2009      COD       Abnorml     139000    86.948260
# 20     2006      New       Partial     325300   119.226675
# 21     2007       WD        Normal     139400    86.307589
# 22     2008       WD        Normal     230000    98.701570
# 23     2007       WD        Normal     129900    64.992307
# 24     2010       WD        Normal     154000    90.807489
# 25     2009       WD        Normal     256300   119.289564
# 26     2010       WD        Normal     134800    84.852814
# 27     2010       WD        Normal     306000   107.135428
# 28     2006       WD        Normal     207500   127.753669
# 29     2008       WD        Normal      68500    79.523581
# ...     ...      ...           ...        ...          ...
# 1430   2006       WD        Normal     192140   148.087812
# 1431   2009       WD        Normal     143750    70.199715
# 1432   2007       WD        Normal      64500   103.923048
# 1433   2008       WD        Normal     186500   101.296594
# 1434   2006       WD        Normal     160000   131.909060
# 1435   2008      COD       Abnorml     174000    91.651514
# 1436   2007       WD        Normal     120500    94.868330
# 1437   2008      New       Partial     394617   111.552678
# 1438   2010       WD        Normal     149700    86.063930
# 1439   2007       WD        Normal     197000   107.628992
# 1440   2008       WD        Normal     191000   107.359210
# 1441   2008       WD        Normal     149300    66.528190
# 1442   2009       WD        Normal     310000   104.895186
# 1443   2009       WD        Normal     121000    94.095696
# 1444   2007       WD        Normal     179600    92.195445
# 1445   2007       WD        Normal     129000    91.651514
# 1446   2010       WD        Normal     157900   161.684879
# 1447   2007       WD        Normal     240000   100.000000
# 1448   2007       WD        Normal     112000   108.475804
# 1449   2006       WD       Abnorml      92000    39.153544
# 1450   2009       WD        Normal     136000    94.868330
# 1451   2009      New       Partial     287090    96.239285
# 1452   2006       WD        Normal     145000    60.621778
# 1453   2006       WD       Abnorml      84500   131.213566
# 1454   2009       WD        Normal     185000    86.602540
# 1455   2007       WD        Normal     175000    88.977525
# 1456   2010       WD        Normal     210000   114.782403
# 1457   2010       WD        Normal     266500    95.089432
# 1458   2010       WD        Normal     142125    98.574845
# 1459   2008       WD        Normal     147500    99.684502
#
# [1460 rows x 83 columns]
